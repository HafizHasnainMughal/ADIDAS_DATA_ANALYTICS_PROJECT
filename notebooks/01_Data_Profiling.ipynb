# %% [markdown]
# first of all we import the libraries
# Library	Purpose
# pandas     >>>	Data read aur analysis
# numpy      >>>  Numerical operations
# matplotlib >>>	Visualization
# seaborn	   >>>  Statistical visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# import the raw data for further processing

# %%
file_path="../data/raw/Adidas_Synthetic_Messy_Data_Analytics_Project.xlsx"
df =pd.read_excel(
    file_path,
    sheet_name="Messy_Raw_Data")

# %% [markdown]
# seeing the random 5 rows in the all data set

# %%
df.sample(5)
# Out:
#         Order_ID              Order_Date Customer_ID    Country  \
# 1703  ORD-101703 1970-01-01 05:00:45.173  CUST-10417    Germany
# 1391  ORD-101391 1970-01-01 05:00:45.505  CUST-10890        USA
# 399   ORD-100399 1970-01-01 05:00:45.968  CUST-10401   Pakistan
# 155   ORD-100155 1970-01-01 05:00:45.409  CUST-10609        USA
# 2085  ORD-102085 1970-01-01 05:00:45.235  CUST-10051  Australia
#
#              Region        City   Category     Product  Gender Size  ...  \
# 1703         Europe      Munich  Lifestyle      Campus    Male   XL  ...
# 1391  North America     Chicago  Lifestyle     Gazelle    Male  NaN  ...
# 399      South Asia  Rawalpindi    Running  Solarboost    Male   44  ...
# 155   North America     Houston  Lifestyle      Campus    Male   42  ...
# 2085        Oceania    Brisbane   Football    Predator  Female   43  ...
#
#      Cost_USD Profit_USD Customer_Rating Returned  Order_Status  Customer_Age  \
# ...

# %% [markdown]
# checking the all data information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3045 entries, 0 to 3044
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Order_ID                     3045 non-null   object
#  1   Order_Date                   3045 non-null   datetime64[ns]
#  2   Customer_ID                  3045 non-null   object
#  3   Country                      3045 non-null   object
#  4   Region                       3045 non-null   object
#  5   City                         2802 non-null   object
#  6   Category                     3045 non-null   object
#  7   Product                      3045 non-null   object
#  8   Gender                       2863 non-null   object
#  9   Size                         2832 non-null   object
#  10  Sales_Channel                3045 non-null   object
#  11  Customer_Segment             3045 non-null   object
# ...

# %% [markdown]
# numerical data summary

# %%
df.describe()
# Out:
#                           Order_Date     Quantity  Unit_Price_USD  \
# count                           3045  3045.000000     3045.000000
# mean   1970-01-01 05:00:45.465020689     1.981938      124.886470
# min       1970-01-01 05:00:44.927000    -1.000000       40.120000
# 25%       1970-01-01 05:00:45.183000     1.000000       89.100000
# 50%       1970-01-01 05:00:45.465000     1.000000      121.340000
# 75%       1970-01-01 05:00:45.744000     2.000000      153.750000
# max       1970-01-01 05:00:46.022000   150.000000      249.630000
# std                              NaN     9.287601       45.553191
#
#        Discount_Rate    Revenue_USD     Cost_USD   Profit_USD  \
# count    2891.000000    3045.000000  3045.000000  3045.000000
# mean        0.119993    1456.138309    92.000814    53.532883
# min        -0.200000   -1000.000000    16.440000   -55.160000
# 25%         0.000000      87.340000    54.850000    27.140000
# ...

# %% [markdown]
# missing values analysis

# %%
missing_values = df.isnull().sum()
missing_values[missing_values > 0].sort_values(ascending=False)
# Out:
# Campaign               723
# Customer_Rating        303
# City                   243
# Size                   213
# Shipping_Days          211
# Marketing_Spend_USD    183
# Gender                 182
# Discount_Rate          154
# Customer_Age           153
# dtype: int64

# %% [markdown]
# calculate the percentage missing values

# %%
missing_percentage = (df.isnull().sum()/ len(df)) * 100

missing_report = pd.DataFrame({
    "Missing_Values": df.isnull().sum(),
    "Missing_Percentage": missing_percentage
})

missing_report[
    missing_report["Missing_Values"] > 0].sort_values(by="Missing_Percentage",ascending=False)
# Out:
#                      Missing_Values  Missing_Percentage
# Campaign                        723           23.743842
# Customer_Rating                 303            9.950739
# City                            243            7.980296
# Size                            213            6.995074
# Shipping_Days                   211            6.929392
# Marketing_Spend_USD             183            6.009852
# Gender                          182            5.977011
# Discount_Rate                   154            5.057471
# Customer_Age                    153            5.024631

# %% [markdown]
# duplicate values ko analysis by order ID

# %%
df.duplicated().sum()
# Out:
# np.int64(45)

# %%
df["Order_ID"].duplicated().sum()
# Out:
# np.int64(45)

# %%
df[df["Order_ID"].duplicated(keep=False)].sort_values("Order_ID")
# Out:
#         Order_ID              Order_Date Customer_ID Country         Region  \
# 44    ORD-100044 1970-01-01 05:00:45.543  CUST-10373     USA  North America
# 3020  ORD-100044 1970-01-01 05:00:45.543  CUST-10373     USA  North America
# 3011  ORD-100052 1970-01-01 05:00:45.400  CUST-10089   India     South Asia
# 52    ORD-100052 1970-01-01 05:00:45.400  CUST-10089   India     South Asia
# 3041  ORD-100063 1970-01-01 05:00:45.068  CUST-10048     USA  North America
# ...          ...                     ...         ...     ...            ...
# 3014  ORD-102776 1970-01-01 05:00:45.381  CUST-10860     UAE    Middle East
# 2851  ORD-102851 1970-01-01 05:00:45.565  CUST-10512     UAE    Middle East
# 3033  ORD-102851 1970-01-01 05:00:45.565  CUST-10512     UAE    Middle East
# 3025  ORD-102895 1970-01-01 05:00:46.013  CUST-10537   India     South Asia
# 2895  ORD-102895 1970-01-01 05:00:46.013  CUST-10537   India     South Asia
#
# ...

# %%
df.columns.tolist()
# Out:
# ['Order_ID',
#  'Order_Date',
#  'Customer_ID',
#  'Country',
#  'Region',
#  'City',
#  'Category',
#  'Product',
#  'Gender',
#  'Size',
#  'Sales_Channel',
#  'Customer_Segment',
#  'Payment_Method',
#  'Campaign',
#  'Quantity',
#  'Unit_Price_USD',
#  'Discount_Rate',
#  'Revenue_USD',
#  'Cost_USD',
#  'Profit_USD',
#  'Customer_Rating',
#  'Returned',
#  'Order_Status',
#  'Customer_Age',
#  'Shipping_Days',
#  'Inventory_Available',
#  'Marketing_Spend_USD',
#  'Customer_Lifetime_Value_USD']

# %% [markdown]
# unique values analyse

# %%
categorical_columns = df.select_dtypes(include="object").columns

for col in categorical_columns:
    print(f"\n{col}")
    print(df[col].nunique())
    print(df[col].unique()[:20])
# Out:
# Order_ID
# 3000
# ['ORD-100000' 'ORD-100001' 'ORD-100002' 'ORD-100003' 'ORD-100004'
#  'ORD-100005' 'ORD-100006' 'ORD-100007' 'ORD-100008' 'ORD-100009'
#  'ORD-100010' 'ORD-100011' 'ORD-100012' 'ORD-100013' 'ORD-100014'
#  'ORD-100015' 'ORD-100016' 'ORD-100017' 'ORD-100018' 'ORD-100019']
#
# Customer_ID
# 862
# ['CUST-10769' 'CUST-10189' 'CUST-10897' 'CUST-10401' 'CUST-10216'
#  'CUST-10230' 'CUST-10642' 'CUST-10484' 'CUST-10339' 'CUST-10317'
#  'CUST-10612' 'CUST-10183' 'CUST-10402' 'CUST-10610' 'CUST-10130'
#  'CUST-10895' 'CUST-10459' 'CUST-10658' 'CUST-10115' 'CUST-10489']
#
# Country
# 13
# ['India' 'Pakistan' 'Saudi Arabia' 'Germany' 'Australia' 'USA' 'UAE' 'UK'
#  'SAUDI ARABIA' 'INDIA' 'GERMANY' 'PAKISTAN' 'AUSTRALIA']
#
# Region
# 5
# ['South Asia' 'Middle East' 'Europe' 'Oceania' 'North America']
#
# City
# 29
# ['Mumbai' 'Karachi' 'Riyadh' 'Berlin' 'Sydney' 'Delhi' nan 'Jeddah'
#  'Melbourne' 'Los Angeles' 'Sharjah' 'Birmingham' 'Dammam' 'Abu Dhabi'
# ...

# %% [markdown]
# identifying the numerical data values

# %%
numeric_columns = df.select_dtypes(include=np.number).columns.tolist()

numeric_columns
# Out:
# ['Quantity',
#  'Unit_Price_USD',
#  'Discount_Rate',
#  'Revenue_USD',
#  'Cost_USD',
#  'Profit_USD',
#  'Customer_Rating',
#  'Customer_Age',
#  'Shipping_Days',
#  'Inventory_Available',
#  'Marketing_Spend_USD',
#  'Customer_Lifetime_Value_USD']

# %% [markdown]
# and for categorical data values

# %%
categorical_columns = df.select_dtypes(include="object").columns.tolist()

categorical_columns
# Out:
# ['Order_ID',
#  'Customer_ID',
#  'Country',
#  'Region',
#  'City',
#  'Category',
#  'Product',
#  'Gender',
#  'Size',
#  'Sales_Channel',
#  'Customer_Segment',
#  'Payment_Method',
#  'Campaign',
#  'Returned',
#  'Order_Status']

# %%
df["Order_Date"].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# first data quality report analysis

# %%
data_quality_report = pd.DataFrame({
    "Column": df.columns,
    "Data_Type": df.dtypes.astype(str),
    "Missing_Values": df.isnull().sum(),
    "Missing_Percentage": (df.isnull().sum() / len(df) * 100),
    "Unique_Values": df.nunique()
})

data_quality_report
# Out:
#                                                   Column       Data_Type  \
# Order_ID                                        Order_ID          object
# Order_Date                                    Order_Date  datetime64[ns]
# Customer_ID                                  Customer_ID          object
# Country                                          Country          object
# Region                                            Region          object
# City                                                City          object
# Category                                        Category          object
# Product                                          Product          object
# Gender                                            Gender          object
# Size                                                Size          object
# Sales_Channel                              Sales_Channel          object
# Customer_Segment                        Customer_Segment          object
# ...
