# %% [markdown]
# for cleaning process we import the python libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# import the data set

# %%
RAW_DATA_PATH="../data/Adidas US Sales Datasets.xlsx"
df = pd.read_excel(RAW_DATA_PATH)

# %% [markdown]
# copy the raw data for backup
# deep=True kyun?
# Yeh raw data ki independent copy banata hai.meand original data per koi effect nahi parta

# %%
df_raw = df.copy(deep=True)

# %% [markdown]
# confirm the duplicate rows

# %%
duplicate_count = df.duplicated().sum()
print(f"the duplicated rows are {duplicate_count}")
# Out:
# the duplicated rows are 1

# %% [markdown]
# remove the exact duplicated rows

# %%
rows_before = len(df)
print(f"rows_before length with duplicate rows {rows_before}")
df = df.drop_duplicates(keep="first").reset_index(drop=True)
rows_after = len(df)
print(f"rows after the  length without duplicate rows {rows_after}")
# Out:
# rows_before length with duplicate rows 9652
# rows after the  length without duplicate rows 9651

# %%
df.shape
# Out:
# (9651, 14)

# %% [markdown]
# column renaming

# %%
df.columns = (
    df.columns
      .str.strip()
      .str.lower()
      .str.replace(" ", "_")
)

# %% [markdown]
#  removeing empty columns

# %%
df.drop(columns=["unnamed:_0"], inplace=True, errors="ignore")

# %%
missing_percentage = (df.isnull().sum()/ len(df)) * 100

missing_report = pd.DataFrame({
    "Missing_Values": df.isnull().sum(),
    "Missing_Percentage": missing_percentage
})

missing_report[
    missing_report["Missing_Values"] > 0].sort_values(by="Missing_Percentage",ascending=False)
# Out:
#              Missing_Values  Missing_Percentage
# unnamed:_1                2            0.020723
# unnamed:_3                2            0.020723
# unnamed:_4                2            0.020723
# unnamed:_5                2            0.020723
# unnamed:_6                2            0.020723
# unnamed:_10               2            0.020723
# unnamed:_7                2            0.020723
# unnamed:_8                2            0.020723
# unnamed:_9                2            0.020723
# unnamed:_12               2            0.020723
# unnamed:_11               2            0.020723
# unnamed:_13               2            0.020723
# unnamed:_2                1            0.010362

# %%
df.to_excel(
    "../data/Adidas_Cleaned_Data.xlsx",
    index=False
)

# %%
clean_data=pd.read_excel("../data/Adidas_Cleaned_Data.xlsx")
clean_data.sample(5)
# Out:
#          unnamed:_1 unnamed:_2           unnamed:_3 unnamed:_4  \
# 9362    Foot Locker    1185732  2021-02-08 00:00:00  Northeast
# 7180      West Gear    1185732  2021-10-17 00:00:00  Northeast
# 6281  Sports Direct    1185732  2021-04-03 00:00:00  Southeast
# 9149        Walmart    1197831  2021-02-21 00:00:00      South
# 1697  Sports Direct    1185732  2021-08-16 00:00:00    Midwest
#
#           unnamed:_5   unnamed:_6               unnamed:_7 unnamed:_8  \
# 9362     Connecticut     Hartford  Women's Street Footwear         18
# 7180   West Virginia   Charleston            Men's Apparel         41
# 6281  North Carolina    Charlotte          Women's Apparel         32
# 9149        Arkansas  Little Rock          Women's Apparel         16
# 1697        Michigan      Detroit          Women's Apparel       50.0
#
#      unnamed:_9 unnamed:_10 unnamed:_11 unnamed:_12 unnamed:_13
# 9362         53         954      410.22        0.43      Outlet
# 7180         53        2173     1195.15        0.55      Online
# 6281        189        6048     3689.28        0.61      Online
# 9149        145        2320       974.4        0.42      Outlet
# 1697        675    337500.0    185625.0        0.55    In-store
